# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Проект-«Телеком»" data-toc-modified-id="Проект-«Телеком»-1">Проект «Телеком»</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1">Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Описание-услуг" data-toc-modified-id="Описание-услуг-1.1.1">Описание услуг</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1.2">Описание данных</a></span></li><li><span><a href="#Критерии-оценки" data-toc-modified-id="Критерии-оценки-1.1.3">Критерии оценки</a></span></li></ul></li><li><span><a href="#План-работы" data-toc-modified-id="План-работы-1.2">План работы</a></span></li><li><span><a href="#Загрузка-библиотек-и-данных" data-toc-modified-id="Загрузка-библиотек-и-данных-1.3">Загрузка библиотек и данных</a></span><ul class="toc-item"><li><span><a href="#Общая-информация-и-форма-таблиц" data-toc-modified-id="Общая-информация-и-форма-таблиц-1.3.1">Общая информация и форма таблиц</a></span></li><li><span><a href="#Наличие-дубликатов-и-пропусков" data-toc-modified-id="Наличие-дубликатов-и-пропусков-1.3.2">Наличие дубликатов и пропусков</a></span></li><li><span><a href="#Наличие-несовпадающих,-уникальных-значений-столбца-customerID" data-toc-modified-id="Наличие-несовпадающих,-уникальных-значений-столбца-customerID-1.3.3">Наличие несовпадающих, уникальных значений столбца <em>customerID</em></a></span></li></ul></li><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-1.4">Объединение таблиц</a></span></li><li><span><a href="#Обработка-образовавшихся-пропусков" data-toc-modified-id="Обработка-образовавшихся-пропусков-1.5">Обработка образовавшихся пропусков</a></span></li><li><span><a href="#Приведение-типов-данных" data-toc-modified-id="Приведение-типов-данных-1.6">Приведение типов данных</a></span></li><li><span><a href="#Анализ-числовых-признаков" data-toc-modified-id="Анализ-числовых-признаков-1.7">Анализ числовых признаков</a></span></li><li><span><a href="#Анализ-категориальных-признаков" data-toc-modified-id="Анализ-категориальных-признаков-1.8">Анализ категориальных признаков</a></span></li><li><span><a href="#Разбитие-на-обучающую-и-валидационную-выборки" data-toc-modified-id="Разбитие-на-обучающую-и-валидационную-выборки-1.9">Разбитие на обучающую и валидационную выборки</a></span></li><li><span><a href="#Выбор-модели-и-гиппер-параметров-на-основе-кросс-валидации" data-toc-modified-id="Выбор-модели-и-гиппер-параметров-на-основе-кросс-валидации-1.10">Выбор модели и гиппер-параметров на основе кросс-валидации</a></span></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-1.11">Тестирование</a></span></li><li><span><a href="#График-важности-признаков" data-toc-modified-id="График-важности-признаков-1.12">График важности признаков</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Проект «Телеком»

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Оператор связи хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# ### Описание услуг

# %% [markdown]
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL) или оптоволоконный кабель (Fiber optic).
#
# Также доступны такие услуги:
#
# - Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*).
# - Выделенная линия технической поддержки (*TechSupport*).
# - Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*).
# - Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные состоят из файлов, полученных из разных источников:
#
# - `contract.csv` — информация о договоре;
# - `personal.csv` — персональные данные клиента;
# - `internet.csv` — информация об интернет-услугах;
# - `phone.csv` — информация об услугах телефонии.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# ### Критерии оценки

# %% [markdown]
# Целевой признак: столбец `EndDate` равен `No`.
#
# Основная метрика: `AUC-ROC`.
#
# Дополнительная метрика: `Accuracy`.
#
# Критерии оценки:
#
# - AUC-ROC < 0.75 — 0 sp
# - 0.75 ≤ AUC-ROC < 0.81 — 4 sp
# - 0.81 ≤ AUC-ROC < 0.85 — 4.5 sp
# - 0.85 ≤ AUC-ROC < 0.87 — 5 sp
# - 0.87 ≤ AUC-ROC < 0.88 — 5.5 sp
# - AUC-ROC ≥ 0.88 — 6 sp

# %% [markdown]
# ## План работы

# %% [markdown]
# 1. Загрузка библиотек и данных
# 2. Предварительное исследование:
#     - формы таблиц
#     - типов данных
#     - дубликатов
#     - пропусков
#     - наличия несовпадающих, уникальных значний столбца `customerID` в таблицах
# 3. Объединение таблиц по столбцу `customerID`
# 4. Обработка образовавшихся пропусков
# 5. Приведение типов данных
# 6. Анализ числовых признаков:
#     - распределение
#     - наличие аномалий
# 7. Анализ категориальных признаков:
#     - наличие дисбаланса
#     - кодирование по необходимости (OE vs OHE)
# 8. Разбитие на обучающую и валидационную выборки
# 9. Разбитие features/target
# 10. Выбор модели и гиппер-параметров на основе кросс-валидации
# 11. Тестирование

# %% [markdown]
# ## Загрузка библиотек и данных

# %%
import os
import re
import pandas as pd
import numpy as np
from IPython.display import HTML
#
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import seaborn as sns
#
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.options.mode.chained_assignment = None
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_columns = None
pd.options.display.max_colwidth = 100

custom_params = {
 'axes.facecolor': '#f5f5f5',
 'axes.edgecolor': 'black',
 'axes.grid': True,
 'axes.axisbelow': 'line',
 'axes.labelcolor': 'black',
 'figure.facecolor': '#f5f5f5',
 'grid.color': 'black',
 'grid.linestyle': ':',
 'text.color': 'black',
 'xtick.color': 'black',
 'ytick.color': 'black',
 'xtick.direction': 'out',
 'ytick.direction': 'out',
 'lines.solid_capstyle': 'round',
 'image.cmap': 'viridis',
 'xtick.bottom': True,
 'ytick.left': True,
 'axes.spines.left': False,
 'axes.spines.bottom': True,
 'axes.spines.right': False,
 'axes.spines.top': False,
 'figure.figsize' : (18,3),
 'figure.dpi' : 80,
 'figure.titlesize' : 20,
 'axes.labelsize' : 16,
 'axes.titlesize' : 16,
 'xtick.labelsize' : 14,
 'ytick.labelsize' : 14,  
                }

sns.set_theme(style="whitegrid", rc=custom_params, palette="twilight")

# %%
try:
    path = r'/datasets/final_provider/'
    print(list(os.walk(path))[0][2])
except:
    path = r'e:\Documents\yandex\final project yandex\datasets'
    print(list(os.walk(path))[0][2])
# Out:
# ['contract.csv', 'internet.csv', 'personal.csv', 'phone.csv']

# %%
df_dict = dict()
df_dict['contract'] = pd.read_csv(os.path.join(path, 'contract.csv'))
df_dict['internet'] = pd.read_csv(os.path.join(path, 'internet.csv'))
df_dict['personal'] = pd.read_csv(os.path.join(path, 'personal.csv'))
df_dict['phone'] = pd.read_csv(os.path.join(path, 'phone.csv'))

# %% [markdown]
# ### Общая информация и форма таблиц

# %%
def info_shape_func(name, df=df_dict):
    display(HTML(f'<code>>>> Таблица {name}</code>:'))
    display(df[name].info())
    display(HTML(f'<code>Форма:</code> <code>{df[name].shape[0]}</code> строк и <code>{df[name].shape[1]}</code> столбцов'))

# %%
for name in df_dict:
    info_shape_func(name)
# Out:
# <code>>>> Таблица contract</code>:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
# None
# <code>Форма:</code> <code>7043</code> строк и <code>8</code> столбцов
# <code>>>> Таблица internet</code>:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ...

# %% [markdown]
# ### Наличие дубликатов и пропусков

# %%
def duplicated_isna_func(name, df=df_dict):
    display(HTML(f'В таблице <code>{name}</code> дубликатов: <code>{df_dict[name].duplicated().sum()}</code>, пропусков: <code>{df_dict[name].isna().sum().sum()}</code>'))

# %%
for name in df_dict:
    duplicated_isna_func(name)
# Out:
# В таблице <code>contract</code> дубликатов: <code>0</code>, пропусков: <code>0</code>
# В таблице <code>internet</code> дубликатов: <code>0</code>, пропусков: <code>0</code>
# В таблице <code>personal</code> дубликатов: <code>0</code>, пропусков: <code>0</code>
# В таблице <code>phone</code> дубликатов: <code>0</code>, пропусков: <code>0</code>

# %% [markdown]
# ### Наличие несовпадающих, уникальных значений столбца *customerID*

# %%
all_customerID = pd.Series()
for name in df_dict:
    all_customerID = all_customerID.append(df_dict[name]['customerID'], ignore_index=True)
display(HTML(f'Количество уникальных ID пользователей во всех таблицах равно <code>{len(all_customerID.unique())}</code>'))
# Out:
# Количество уникальных ID пользователей во всех таблицах равно <code>7043</code>

# %% [markdown]
# Таким образом, столбец `customerID` не содержит несовпадающих или уникальных значений. Таблицы можно сливать в одну

# %% [markdown]
# ## Объединение таблиц

# %%
df = df_dict['contract'].merge(df_dict['personal'], on='customerID')\
.merge(df_dict['internet'], how='left', on='customerID')\
.merge(df_dict['phone'], how='left', on='customerID')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   int64
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  InternetService   5517 non-null   object
#  13  OnlineSecurity    5517 non-null   object
#  14  OnlineBackup      5517 non-null   object
#  15  DeviceProtection  5517 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# customerID             0
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# MultipleLines        682
# dtype: int64

# %%
df.astype('object').describe().T
# Out:
#                     count   unique               top  freq
# customerID           7043     7043        7590-VHVEG     1
# BeginDate            7043       77        2014-02-01   366
# EndDate              7043        5                No  5174
# Type                 7043        3    Month-to-month  3875
# PaperlessBilling     7043        2               Yes  4171
# PaymentMethod        7043        4  Electronic check  2365
# MonthlyCharges   7,043.00 1,585.00             20.05 61.00
# TotalCharges         7043     6531                      11
# gender               7043        2              Male  3555
# SeniorCitizen        7043        2                 0  5901
# Partner              7043        2                No  3641
# Dependents           7043        2                No  4933
# InternetService      5517        2       Fiber optic  3096
# OnlineSecurity       5517        2                No  3498
# OnlineBackup         5517        2                No  3088
# ...

# %% [markdown]
# ## Обработка образовавшихся пропусков

# %%
df = df.fillna('not_use')

# %% [markdown]
# ## Приведение типов данных

# %% [markdown]
# На основе `EndDate` создадим столбец с целевым признаком `target`:

# %%
df['target'] = df['EndDate'].apply(lambda x: 0 if x == 'No' else 1)

# %% [markdown]
# Создадим признак дней "времени жизни" клиента `LiveTime`:

# %%
df['EndDate'] = df['EndDate'].apply(lambda x: '2020-02-01' if x == 'No' else x.split(' ')[0])
df['BeginDate'] = pd.to_datetime(df.loc[:,'BeginDate'])
df['EndDate'] = pd.to_datetime(df.loc[:,'EndDate'])
df['LiveTime'] = (df['EndDate'] - df['BeginDate']).dt.days

# %% [markdown]
# Перед приведением `TotalCharges` к типу `float64` проанализируем содержимое столбца

# %%
df[~df['TotalCharges'].str.contains('\d', flags=re.IGNORECASE)].index == df[df['BeginDate'] == '2020-02-01'].index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %% [markdown]
# Пустые значения соответствуют дате заключения договора `2020-02-01`, а значит это новые клиенты и их можно не учитывать при создании модели

# %%
df = df[~(df['BeginDate'] == '2020-02-01')].reset_index(drop=True)

# %%
df['TotalCharges'] = df['TotalCharges'].astype('float64')

# %% [markdown]
# Создадим списки названий категориальных (`category_columns`) и числовых (`numeric_columns`) признаков:

# %%
category_columns = df.iloc[:,3:-1].select_dtypes(include=['object','int64']).columns
df[category_columns] = df[category_columns].astype('category')
numeric_columns = df.select_dtypes(include=['float64','int64']).columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   BeginDate         7032 non-null   datetime64[ns]
#  2   EndDate           7032 non-null   datetime64[ns]
#  3   Type              7032 non-null   category
#  4   PaperlessBilling  7032 non-null   category
#  5   PaymentMethod     7032 non-null   category
#  6   MonthlyCharges    7032 non-null   float64
#  7   TotalCharges      7032 non-null   float64
#  8   gender            7032 non-null   category
#  9   SeniorCitizen     7032 non-null   category
#  10  Partner           7032 non-null   category
#  11  Dependents        7032 non-null   category
#  12  InternetService   7032 non-null   category
#  13  OnlineSecurity    7032 non-null   category
#  14  OnlineBackup      7032 non-null   category
# ...

# %% [markdown]
# ## Анализ числовых признаков

# %%
fig = plt.figure(figsize=(18,5))
fig.suptitle(f'Распределение числовых переменных', x=.5, y=1, fontsize=18)
for i, col in enumerate(numeric_columns, start=1):
    plt.subplot(1,len(numeric_columns),i)
    sns.histplot(df[col], stat='density', kde=True)#, bins=30
    plt.ylabel('')
    plt.xlabel('')
    plt.grid(True, linestyle=':', linewidth=1)
    plt.tick_params(direction='out', length=2, labelsize=12, width=1)
    plt.title(f'{col}', pad=2, fontsize=14, ha='left', position=(0,1))

# %%
fig = plt.figure(figsize=(18,2))
fig.suptitle(f'Распределение числовых переменных', x=.5, y=1.2, fontsize=18)
for i, col in enumerate(numeric_columns, start=1):
    plt.subplot(1,len(numeric_columns),i)
    sns.boxplot(df[col], orient='h', notch=True)
    plt.grid(True, linestyle=':', linewidth=1)
    plt.yticks([])
    plt.ylabel('')
    plt.xlabel('')
    plt.tick_params(direction='out', length=2, labelsize=12, width=1)
    plt.title(f'{col}', fontsize=14, ha='left', position=(0,1))

# %%
df.corr()
# Out:
#                 MonthlyCharges  TotalCharges  LiveTime
# MonthlyCharges            1.00          0.65      0.25
# TotalCharges              0.65          1.00      0.83
# LiveTime                  0.25          0.83      1.00

# %% [markdown]
# Столбец `TotalCharges` высоко коррелирует с признаком `LiveTime`

# %% [markdown]
# ## Анализ категориальных признаков

# %%
fig = plt.figure(figsize=(20,20))
fig.suptitle(f'Распределение категориальных переменных', x=.5, y=0.92, fontsize=18)#
for i, col in enumerate(category_columns, start=1):
    x = df[col].value_counts(normalize=True).index
    y = df[col].value_counts(normalize=True)
    c_list = list(sns.color_palette())[:len(x)]
    c_patch = []
    for c in c_list:
        c_patch.append(mpatches.Patch(color=c, alpha=0.62, linewidth=1, edgecolor='black'))
    plt.subplot(len(category_columns) // 4, len(category_columns) // 4, i)
    sns.barplot(x=x, y=y, order=x, alpha=0.62, linewidth=1, edgecolor='black')
    plt.legend(handles=c_patch, labels=x.to_list(), fontsize=14)
    plt.grid(True, axis='y', linestyle=':', linewidth=1)
    plt.tick_params(axis='y', direction='out', length=0, width=1)
    plt.ylabel('')
    plt.yticks(np.arange(0.00, 1.01, step=0.10), fontsize=10)
    plt.xticks([])
    plt.title(f'{col}', fontsize=14, ha='left', position=(0,1))

# %% [markdown]
# ## Разбитие на обучающую и валидационную выборки

# %% [markdown]
# Для построения модели не будем учитывать следующие признаки:

# %%
X = df.drop(columns=['customerID', 'BeginDate', 'EndDate', 'TotalCharges', 'target'])
y = df['target'].astype('int64')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12345)

# %% [markdown]
# ## Выбор модели и гиппер-параметров на основе кросс-валидации

# %% [markdown]
# В качестве модели будем использовать классификатор `CatBoost`, т.к. данная модель способна работать с категориальными признаками без дополнительного кодирования

# %%
best_score = 0
estimators = None
for i in np.arange(190, 211, 1):
    model = CatBoostClassifier(n_estimators=i,
                               learning_rate=0.99,
                               depth=3,
                               cat_features=category_columns.drop('target').to_list(),
                               verbose=False,
                               random_state=12345
                              )

    score = np.mean(cross_val_score(model, X_train, y_train, cv=4, scoring='roc_auc'))
    
    if score > best_score:
        best_score = score
        estimators = i
display(HTML(f'<b>n_estimators = </b> <code>{estimators}</code>'))
display(HTML(f'<b>Лучшее AUC-ROC = </b> <code>{best_score:,.4f}</code>'))
# Out:
# <b>n_estimators = </b> <code>201</code>
# <b>Лучшее AUC-ROC = </b> <code>0.9213</code>

# %% [markdown]
# ## Тестирование

# %%
model = CatBoostClassifier(n_estimators=estimators,
                           learning_rate=0.99,
                           depth=3,
                           cat_features=category_columns.drop('target').to_list(),
                           verbose=False,
                           random_state=12345
                          )
model.fit(X_train, y_train)

f1_score_test = f1_score(y_test, model.predict(X_test), average='macro')
roc_auc_test = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])

display(HTML(f'<b>f1_score на тестовой выборке равен: </b> <code>{f1_score_test:,.4f}</code>'))
display(HTML(f'<b>AUC-ROC на тестовой выборке равен: </b> <code>{roc_auc_test:,.4f}</code>'))
# Out:
# <b>f1_score на тестовой выборке равен: </b> <code>0.8422</code>
# <b>AUC-ROC на тестовой выборке равен: </b> <code>0.9273</code>

# %% [markdown]
# ## График важности признаков

# %%
fi = pd.DataFrame({'feature_importances':model.feature_importances_}, index=X.columns).sort_values(by='feature_importances', ascending=False)

# %%
fig = plt.figure(figsize=(20,8))
fig.suptitle(f'График важности признаков', x=.5, y=.95, fontsize=18)
sns.barplot(data=fi, x='feature_importances', y=fi.index, linewidth=0.5, edgecolor='black')
plt.grid(True, axis='x', linestyle=':', linewidth=1)
plt.tick_params(axis='both', direction='out', length=0, width=1)
plt.ylabel('')
plt.xlabel('')
plt.yticks(fontsize=14)
plt.xticks(list(range(0,91,10)), fontsize=14)
plt.show()

# %%
fi
# Out:
#                   feature_importances
# LiveTime                        74.10
# MonthlyCharges                   9.43
# Type                             3.99
# OnlineSecurity                   2.80
# PaymentMethod                    1.57
# MultipleLines                    1.51
# SeniorCitizen                    1.44
# TechSupport                      1.08
# OnlineBackup                     0.82
# StreamingMovies                  0.62
# StreamingTV                      0.57
# DeviceProtection                 0.54
# InternetService                  0.45
# PaperlessBilling                 0.42
# gender                           0.29
# Dependents                       0.28
# Partner                          0.08
